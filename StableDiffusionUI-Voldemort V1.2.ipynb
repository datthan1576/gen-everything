# %% [markdown]
# Adapted from: https://colab.research.google.com/drive/1AfAmwLMd_Vx33O9IwY2TmO9wKZ8ABRRa

# %%
import os
os.kill(os.getpid(), 9) # This will crash Colab (required, everything will still be intact so dont worry)

# %% [markdown]
# Clone webui repository

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 6670, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 6670 (delta 73), reused 76 (delta 52), pack-reused 6541
# Receiving objects: 100% (6670/6670), 21.73 MiB | 34.77 MiB/s, done.
# Resolving deltas: 100% (4702/4702), done.
# /content/stable-diffusion-webui

# %% [markdown]
# Download the model from huggingface. See link at the start for different ways.

# %%
#@title Normal 1.4 model
# get a token from https://huggingface.co/settings/tokens
user_token = "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" #@param {type:"string"}
user_header = f"\"Authorization: Bearer {user_token}\""
# !wget --header={user_header} https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/model.ckpt
# Out:
# --2022-10-17 07:00:47--  https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt
# Resolving huggingface.co (huggingface.co)... 52.5.54.249, 44.195.102.200, 54.210.225.113, ...
# Connecting to huggingface.co (huggingface.co)|52.5.54.249|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/4c/37/4c372b4ebb57bbd02e68413d4951aa326d4b3cfb6e62db989e529c6d4b26fb21/fe4efff1e174c627256e44ec2991ba279b3816e364b49f9be2abc0b3ff3f8556?response-content-disposition=attachment%3B%20filename%3D%22sd-v1-4.ckpt%22&Expires=1666245652&Policy=...&Signature=KqxtqS5NkW~IrUX5GotfUJcfLtsRTfsBqJQ~aGNRfeqkAJ~XuGeStLYo0gGmX41WnkWkQb0AfwxipGmKSA5J5NRe2ZHycBLDgOCaeVBBASV9bk94foAqxnv1PLg5mzxWArIc2SfJk9nmaWXkJiYExxLQ3jjcYW0AipJjJkA~Eofhi21EdEiyqNtgMwB~YfX2o409uDswxRpGtpnwEeqgtQ8wc-ENLajsRoxV5Y5ph~sBrsw5Z1puoAXiAJxttnu~-N6w6oAiroqeohWJsbRpiifjuEMrOctolThmkROyG4J5Zt7gEkVG7SH5Z1OJHQpDlsxmB1e-qVXUuhk8duY~xw__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2022-10-17 07:00:47--  https://cdn-lfs.huggingface.co/repos/4c/37/4c372b4ebb57bbd02e68413d4951aa326d4b3cfb6e62db989e529c6d4b26fb21/fe4efff1e174c627256e44ec2991ba279b3816e364b49f9be2abc0b3ff3f8556?response-content-disposition=attachment%3B%20filename%3D%22sd-v1-4.ckpt%22&Expires=1666245652&Policy=...&Signature=KqxtqS5NkW~IrUX5GotfUJcfLtsRTfsBqJQ~aGNRfeqkAJ~XuGeStLYo0gGmX41WnkWkQb0AfwxipGmKSA5J5NRe2ZHycBLDgOCaeVBBASV9bk94foAqxnv1PLg5mzxWArIc2SfJk9nmaWXkJiYExxLQ3jjcYW0AipJjJkA~Eofhi21EdEiyqNtgMwB~YfX2o409uDswxRpGtpnwEeqgtQ8wc-ENLajsRoxV5Y5ph~sBrsw5Z1puoAXiAJxttnu~-N6w6oAiroqeohWJsbRpiifjuEMrOctolThmkROyG4J5Zt7gEkVG7SH5Z1OJHQpDlsxmB1e-qVXUuhk8duY~xw__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.65.229.35, 18.65.229.73, 18.65.229.83, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.65.229.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4265380512 (4.0G) [binary/octet-stream]
# Saving to: ‘/content/stable-diffusion-webui/model.ckpt’
#
# /content/stable-dif 100%[===================>]   3.97G   241MB/s    in 17s
#
# 2022-10-17 07:01:04 (244 MB/s) - ‘/content/stable-diffusion-webui/model.ckpt’ saved [4265380512/4265380512]

# %% [markdown]
# Voldy doesn't explian what this does but it appears to replace the prior dependencies section, saving a few lines lmao

# %%
# !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.7.14 (default, Sep  8 2022, 00:06:44)
# [GCC 7.5.0]
# Commit hash: cccc5a20fce4bde9a4299f8790366790735f1d05
# Installing gfpgan
# Installing clip
# Cloning Stable Diffusion into repositories/stable-diffusion...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Exiting because of --exit argument

# %% [markdown]
# Change into Web UI directory and download updates

# %%
# %cd /content/stable-diffusion-webui
# !git pull
# Out:
# /content/stable-diffusion-webui
# Already up to date.

# %% [markdown]
# Launch web ui. You will get a link to nnn.gradio.app, follow it.
#
# Commandline arguments are:
#   - `--share` - create online gradio.app link
#   - `--gradio-debug` - print outputs to console
#   - `--gradio-auth me:qwerty` - add authentication to gradio: username me, password qwerty

# %%
# !COMMANDLINE_ARGS="--share --gradio-debug --gradio-auth dat:dat" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.7.14 (default, Sep  8 2022, 00:06:44)
# [GCC 7.5.0]
# Commit hash: cccc5a20fce4bde9a4299f8790366790735f1d05
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug --gradio-auth dat:dat
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Loading weights [7460a6fa] from /content/stable-diffusion-webui/model.ckpt

# %% [markdown]
# commands for ***after*** you have gotten done with a session
# ============================================================================

# %% [markdown]
# Zip images for downloading on local drive (click the folder icon on the left, the one below {x})

# %%
# !zip -r /content/stable-diffusion-webui /content/stable-diffusion-webui/outputs

# %% [markdown]
# Save images to Google Drive **Warning: this will cause google to scan your drive, so if you intend to use this and worry about that kind of stuff, probablly just set this up on a clean account that's just for this colab**

# %%
from google.colab import drive # type: ignore

try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
except:
   print("...error mounting drive or with drive path variables")

# !cp -r "/content/stable-diffusion-webui/outputs" "/content/drive/MyDrive"
